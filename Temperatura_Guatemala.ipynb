# %%
import pandas as pd
import matplotlib.pyplot as plt

#Importación del CSV
data = pd.read_csv("CSV_LIMPIOS\Temperatura_Guatemala.csv") 

#Conversión a numérico
data['Años__ESTANDAR'] = pd.to_numeric(data['Años__ESTANDAR'])
data['value'] = pd.to_numeric(data['value'])

#Creación de la gráfica
plt.figure(figsize=(10, 6))
plt.plot(data['Años__ESTANDAR'], data['value'], marker='o', linestyle='-', color='green', label="°C")

#Personalización
plt.title("Variación de temperatura media en Guatemala (1999-2019)")
plt.xlabel("Año")
plt.ylabel("Temperatura (°C))")
plt.legend()
plt.grid()

plt.savefig('GRAFICAS/Temperatura_Guatemala.png', dpi=300)
print("Gráfica guardada como GRAFICAS/Temperatura_Guatemala.png")


plt.show()
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\T'
# <>:5: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\i5\AppData\Local\Temp\ipykernel_18528\3508518959.py:5: SyntaxWarning: invalid escape sequence '\T'
#   data = pd.read_csv("CSV_LIMPIOS\Temperatura_Guatemala.csv")
# Gráfica guardada como GRAFICAS/Temperatura_Guatemala.png
